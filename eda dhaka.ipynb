# %%
import pandas as pd 
df = pd.read_csv('DSE Scraped.csv')
df.head()
# Out:
#   Trading Code                     Company Name Last Trading Price  \
# 0    1JANATAMF    First Janata Bank Mutual Fund               6.20
# 1   1STPRIMFMF  Prime Finance First Mutual Fund              17.20
# 2     AAMRANET           aamra networks limited              39.30
# 3    AAMRATECH       aamra technologies limited              31.10
# 4     ABB1STMF          AB Bank 1st Mutual fund               5.30
#
#   Closing Price Last Update    Day's Range Change* Day's Value (mn) Change(%)  \
# 0          6.20     3:45 PM    6.20 - 6.30       0             1.75     0.00%
# 1         17.10     3:45 PM  17.00 - 17.30    -0.1             2.87    -0.58%
# 2         39.30     3:45 PM  38.00 - 39.60     0.6            68.20     1.55%
# 3         31.10     3:45 PM  30.50 - 31.70       0            13.24     0.00%
# 4          5.30     3:45 PM    5.20 - 5.30       0             1.27     0.00%
#
#   52 Weeks' Moving Range  ...        Sector  \
# 0           5.70 - 10.00  ...  Mutual Funds
# ...

# %% [markdown]
# Last Trading Price: Updated price of last trade.
#
# Closing Price: The last price when trading day was end.
#
# Day's Range: Lowest and Highest price of the day
#
# Change:
#
# Day's Value (mn):
#
# Day's Volume: How many shares has been traded tody
#
# Change(%):
#
# 52 Weeks' Moving Range: Lowest and Highest price of last 52 weeks
#
# Day's Trade:
#
# Market Capitalization (mn):
#
# Authorized Capital (mn):
#
# Debut Trading Date: Date of 1st trade in Stock market.
#
# Paid-up Capital (mn):
#
# Face par value: Original cost per stock, which should be paid to the holder.
#
# Total No. of Outstanding Securities: Remaining Security Balence held by company.

# %%
df.isnull().sum()
# Out:
# Trading Code                             0
# Company Name                             0
# Last Trading Price                       0
# Closing Price                            0
# Last Update                              0
# Day's Range                              0
# Change*                                  0
# Day's Value (mn)                         0
# Change(%)                                0
# 52 Weeks' Moving Range                   0
# Opening Price                            0
# Day's Volume (Nos.)                      0
# Adjusted Opening Price                   0
# Day's Trade (Nos.)                       0
# Yesterday's Closing Price                0
# Market Capitalization (mn)               0
# Authorized Capital (mn)                  0
# Debut Trading Date                     251
# Paid-up Capital (mn)                     0
# Type of Instrument                       0
# Face/par Value                           0
# Market Lot                               0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 33 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Trading Code                         383 non-null    object
#  1   Company Name                         383 non-null    object
#  2   Last Trading Price                   383 non-null    object
#  3   Closing Price                        383 non-null    object
#  4   Last Update                          383 non-null    object
#  5   Day's Range                          383 non-null    object
#  6   Change*                              383 non-null    object
#  7   Day's Value (mn)                     383 non-null    object
#  8   Change(%)                            383 non-null    object
#  9   52 Weeks' Moving Range               383 non-null    object
#  10  Opening Price                        383 non-null    object
# ...

# %%
import numpy as np
stock_data = df.copy()
count = 0

for col in stock_data:
    for i, data in enumerate(stock_data[col]):
        if data == "-":
            stock_data[col][i] = np.NaN
            count+=1
            print(f"{count}. Replaced with NaN in {i}th of {col}")
# Out:
# 1. Replaced with NaN in 81th of Last Trading Price
# 2. Replaced with NaN in 82th of Last Trading Price
# 3. Replaced with NaN in 81th of Closing Price
# 4. Replaced with NaN in 82th of Closing Price
# 5. Replaced with NaN in 81th of Day's Range
# 6. Replaced with NaN in 82th of Day's Range
# 7. Replaced with NaN in 81th of Change*
# 8. Replaced with NaN in 82th of Change*
# 9. Replaced with NaN in 81th of Day's Value (mn)
# 10. Replaced with NaN in 82th of Day's Value (mn)
# 11. Replaced with NaN in 374th of Day's Value (mn)
# 12. Replaced with NaN in 81th of Change(%)
# 13. Replaced with NaN in 82th of Change(%)
# 14. Replaced with NaN in 81th of Opening Price
# 15. Replaced with NaN in 82th of Opening Price
# 16. Replaced with NaN in 81th of Day's Volume (Nos.)
# 17. Replaced with NaN in 82th of Day's Volume (Nos.)
# 18. Replaced with NaN in 81th of Adjusted Opening Price
# 19. Replaced with NaN in 82th of Adjusted Opening Price
# ...

# %%
print(df.info()); print('\n'); print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 33 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Trading Code                         383 non-null    object
#  1   Company Name                         383 non-null    object
#  2   Last Trading Price                   383 non-null    object
#  3   Closing Price                        383 non-null    object
#  4   Last Update                          383 non-null    object
#  5   Day's Range                          383 non-null    object
#  6   Change*                              383 non-null    object
#  7   Day's Value (mn)                     383 non-null    object
#  8   Change(%)                            383 non-null    object
#  9   52 Weeks' Moving Range               383 non-null    object
#  10  Opening Price                        383 non-null    object
# ...
